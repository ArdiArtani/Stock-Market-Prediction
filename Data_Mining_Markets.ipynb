# %% [markdown]
# <a href="https://colab.research.google.com/github/ArdiArtani/Stock-Market-Prediction/blob/main/Data_Mining_Markets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Collection
#
# We used [Alpha Vantage](https://alphavantage.co) as our API source for historical and real time stock market data.
#
# Note to self: we may change to yfinance.

# %%
# libraries needed
pip install alpha-vantage

# %%
# importing libraries
from alpha_vantage.timeseries import TimeSeries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

API key, do not abuse! >:|
key = 'XXXXXXXXXX'

# Data Selection
ts = TimeSeries(key, output_format='pandas')
data, meta = ts.get_intraday('AAPL', interval='1min', outputsize='full')

data
# Out:
#                      1. open  2. high    3. low  4. close  5. volume
# date
# 2021-11-29 20:00:00   160.57   160.63  160.5700    160.63     3262.0
# 2021-11-29 19:59:00   160.57   160.60  160.5500    160.57     3162.0
# 2021-11-29 19:58:00   160.56   160.56  160.5499    160.55     2695.0
# 2021-11-29 19:57:00   160.59   160.59  160.5900    160.59      750.0
# 2021-11-29 19:56:00   160.57   160.58  160.5600    160.57     3202.0
# ...                      ...      ...       ...       ...        ...
# 2021-11-16 04:36:00   149.76   149.76  149.7500    149.75      929.0
# 2021-11-16 04:35:00   149.76   149.76  149.7500    149.75     4243.0
# 2021-11-16 04:34:00   149.79   149.79  149.7500    149.75      534.0
# 2021-11-16 04:33:00   149.80   149.80  149.7900    149.79     1579.0
# 2021-11-16 04:02:00   149.92   149.92  149.9200    149.92      654.0
#
# [7068 rows x 5 columns]

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

plt.plot(data['4. close'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Data Analysis

# %%
import sklearn
import pandas as pd

# %% [markdown]
# # Conclusions
#
# (paste in 5-pg essay here)
